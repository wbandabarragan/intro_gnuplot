# %% [markdown]
# ### 7.3. CONTROL DE TAMAÑO DE FUENTE

# %% [markdown]
# Recapitulamos:

# %%
reset 

set title "Función e^{|x|}"

set xrange[-4:4]
set yrange[0:50]

set key left bottom

set tics #Modifica el tamaño de letra de los ejes. En este caso de los números.
set xtics -4,2,4
set ytics 0,10,50

set xlabel "Eje X" offset -6,+1.5
set ylabel "Eje Y" rotate by 0 offset +1.5,0

plot exp(abs(x)) title " y = e^{|x|}"
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# Podemos controlar el tamaño de letra con <b> font ",número"</b>
#
# Y los tamaños se especifican de manera usual: 8, 10, 12, 14, 16, etc.

# %%
reset 

set title "Función e^{|x|}" font ",13"

set xrange[-4:4]
set yrange[0:50]

set key left bottom font ",13"

set tics font ",13" #Modifica el tamaño de letra de los ejes. En este caso de los números.
set xtics -4,2,4
set ytics 0,10,50

set xlabel "Eje X" font ",13" offset -6,+1.5
set ylabel "Eje Y" font ",13" rotate by 0 offset +1.5,0

plot exp(abs(x)) title " y = e^{|x|}"
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# ### 7.4. COLORES Y ANCHOS DE LÍNEA

# %% [markdown]
# Podemos controlar el color y ancho de líneas con <b> linecolor "color"</b> y con <b> linewidth "número"</b>
#
# Los colores se especifican de acuerdo a un número: 1, 2, 3, 4, 5, etc.
# Los anchos se especifican de manera usual: 1, 2, 3, 4.

# %%
reset 

set title "Función y=e^{|x|}" font ",14"

set xrange[-4:4]
set yrange[0:50]

set grid #Para ubicar la grilla

set key top center font ",14" #Noten que también cambiamos la localización del key.

set tics font ",14"
set xtics -4,2,4
set ytics 0,10,50

set xlabel "Eje X" font ",14" offset -6,+1.5
set ylabel "Eje Y" font ",14" rotate by 0 offset +1.5,0

plot exp(abs(x)) title " y = e^{|x|}" linecolor 2 linewidth 3
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# También funciona con los diminutivos <b>lc</b> y <b>lw</b> de <b>linecolor "color"</b> y con <b>linewidth "número"</b>, respectivamente.

# %%
reset 

set title "Función y=e^{|x|}" font ",14"

set xrange[-4:4]
set yrange[0:50]

set grid #Para ubicar la grilla

set key top center font ",14" #Noten que también cambiamos la localización del key.

set tics font ",14"
set xtics -4,2,4
set ytics 0,10,50

set xlabel "Eje X" font ",14" offset -6,+1.5
set ylabel "Eje Y" font ",14" rotate by 0 offset +1.5,0

plot exp(abs(x)) title " y = e^{|x|}" lc 2 lw 3
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# Además, podemos utilizar <b>dashtype número</b> para líneas entrecortadas:

# %%
reset 

set title "Función y=e^{|x|}" font ",14"

set xrange[-4:4]
set yrange[0:50]

set key top center font ",14"

set tics font ",14" #Modifica el tamaño de letra de los ejes. En este caso de los números.
set xtics -4,2,4
set ytics 0,10,50

set xlabel "{/Symbol b}" font ",14" offset -7,+1.5
set ylabel "{/Symbol e}" font ",14" rotate by -1 offset +1.5,0

plot exp(abs(x)) title " y = e^{|x|}" linecolor 4 linewidth 4 dashtype 3, 5*x**2 title " y = x^2" linecolor 3 linewidth 5 dashtype 4
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# Para el ancho de los bordes, utilizamos:
#
# <b>set border linewidth número</b>
#
# como sigue:

# %%
reset 

set title "Función y=e^{|x|}" font ",14"
set border linewidth 3

set xrange[-4:4]
set yrange[0:50]

set grid linewidth 1

set key at 0,47
set key font ",14"

set tics font ",14"
set xtics -4,2,4
set ytics 0,10,50

set xlabel "{/Symbol b}" font ",14" offset -6,+1.5
set ylabel "{/Symbol e}" font ",14" rotate by 0 offset 0,0

plot exp(abs(x)) title " y = e^{|x|}" linecolor 4 linewidth 3 dashtype 3, 5*x**2 title " y = x^2" linecolor 3 linewidth 3 dashtype 4
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# En el caso de plots de superficies, podemos utilizar:
#
# <b>set view ROT_X, ROT_Z, ESCALA</b>
#
# para controlar los ángulos de vista:

# %%
reset

set key rmargin top # Abajo del margen - Éste es un comentario

set parametric

set isosamples 50,50 #Define iso-superficies

set hidden3d # Oculta líneas no visibles

set title "Donas entrecruzadas"

set xlabel "{/Symbol a}" offset -1,-0.5
set ylabel "{/Symbol b}" offset -2.0,-0.5
set zlabel "{/Symbol g}" offset +1.0,-0.5

set urange [-pi:pi]
set vrange [-pi:pi]

# Ángulos de rotación y escala

set view 40,20,1.1

# Podemos asignar colores a splot con linecolor 

splot cos(u)+0.5*cos(u)*cos(v),sin(u)+0.5*sin(u)*cos(v),0.5*sin(v) title "Dona 1" linecolor 3,1+cos(u)+0.5*cos(u)*cos(v),0.5*sin(v),sin(u)+0.5*sin(u)*cos(v) title "Dona 2" linecolor 4
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.
# 	dummy variable is t for curves, u/v for surfaces

# %% [markdown]
# Otros ejemplos:

# %%
reset 

set xrange [-pi/2:pi/2]

set yrange [-pi/2:pi/2]

#set style function linespoints
set key lmargin top

set palette rgb 23,28,3

set view 40,20,1

set contour #Para contornos
set pm3d #Para gráficos 3D
set hidden3d #Para ocultar lugares no visibles.

set isosamples 20,20

set samples 10,10

splot sin(x)*sin(y)
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# ## 8. Lectura de datos

# %% [markdown]
# En forma general, utilizamos el comando <b>plot</b> seguido por "<b>el nombre del archivo entre comillas</b>" y el comando <b>using</b> para indicar el orden de las columnas.
#
# El comando <b>plot</b> asume que el fichero es un archivo de texto, separado por espacios o "tabs".

# %% [markdown]
# ### 8.1. Ficheros de texto:

# %%
reset

plot "ejemplo_datos_1.dat" using 1:2

#plot "ejemplo_datos_1.dat" using 2:1

# %% [markdown]
# Noten que por defecto plotea los datos con "points". Podemos usar </b>with lines</b> para graficar con líneas.

# %%
reset

plot "ejemplo_datos_1.dat" using 1:2 with lines
# Out:
# An unknown error occured. Failed to read and display image file from gnuplot.

# %% [markdown]
# Otra alternativa para visualizar los datos como líneas es utilizar el comando:
#
# <b>set style data lines</b>
#
# Que, de hecho, es más conveniente.
#
# Otros estilos incluyen:

# %%
help plotting styles

# %% [markdown]
# Por ejemplo, tomemos otro de los archivos de ejemplo:
#
#         ejemplo_datos_0.dat

# %%
reset 

set style data points

plot "ejemplo_datos_0.dat" using 1:2
# Out:
# Subtopics available for plotting styles:
#     3D                boxerrorbars      boxes             boxplot
#     boxxyerror        candlesticks      circles           dots
#     ellipses          errorbars         errorlines        filledcurves
#     financebars       fsteps            histeps           histograms
#     image             impulses          labels            lines
#     linespoints       points            rgbalpha          rgbimage
#     steps             vectors           xerrorbars        xerrorlines
#     xyerrorbars       xyerrorlines      yerrorbars        yerrorlines
#     zerrorfill
#
#
#  Many plotting styles are available in gnuplot.
#  They are listed alphabetically below.
#  The commands `set style data` and `set style function` change the
#  default plotting style for subsequent `plot` and `splot` commands.
#
#  You can also specify the plot style explicitly as part of
#  the `plot` or `splot` command.  If you want to mix plot styles within a
# ...

# %% [markdown]
# Para graficar con ambos: puntos y líneas, usamos <b>linespoints</b> (el diminutivo es <b>lp</b>):

# %%
reset 

set style data linespoints #Para superponer puntos y líneas

plot "ejemplo_datos_0.dat" using 1:2 linecolor 2

# %% [markdown]
# Otra alternativa para combinar líneas y puntos de un mismo conjunto de datos es utilizar:
#
#         set style data lines
#
# Como sigue a continuación:

# %%
reset 

set style data lines

plot "ejemplo_datos_0.dat" using 1:2 with lines linecolor 2 linewidth 3, "ejemplo_datos_0.dat" using 1:2 with points pointtype 5 pointsize 1 linecolor rgb "red" notitle

#Noten que también podemos utilizar linecolor rgb (código red green blue) para definir el color.

# %% [markdown]
# El comando <b>using</b> puede usarse para realizar operaciones con las columnas del fichero fuente.
#
# Para hacerlo accedemos a los datos con el símbolo $\$ COLUMNA$ y operarmos de forma usual, e.g.:
#
# (\$1/2):(\$2*3)

# %%
reset 

set style data lines

plot "ejemplo_datos_0.dat" using ($1/2):2 with lines linecolor 2 linewidth 2, "ejemplo_datos_0.dat" using ($1/2):2 with points pointtype 1 pointsize 1 linecolor rgb "red" notitle

#Noten que también podemos utilizar linecolor rgb (código red green blue) para definir el color.

# %% [markdown]
# Para plotear varios gráficos, podemos separar las curvas con comas en una sola línea del comando <b>plot</b>:

# %%
reset 

set style data lines

plot "ejemplo_datos_0.dat" using 1:2 linecolor 2 linewidth 2, "ejemplo_datos_0.dat" using 1:3 linecolor 3 linewidth 2

# %% [markdown]
# Además, podemos utilizar escala logarítmica con el comando:
#
#         set logscale x/y

# %%
reset 

set style data lines

set logscale y

plot "ejemplo_datos_0.dat" using 1:2 linecolor 2 linewidth 2, "ejemplo_datos_0.dat" using 1:3 linecolor 3 linewidth 2

# %% [markdown]
# Para plotear varios gráficos de distintos archivos, también podemos separar las curvas con comas en una sola línea del comando <b>plot</b>:

# %%
reset 

set style data lines

plot "pdf_f00.dat" using 1:2 linecolor 2 linewidth 2, "pdf_f15.dat" using 1:2 linecolor 3 linewidth 2

# %% [markdown]
# En la mayoría de casos resulta conveniente definir los estilos de línea antes de usarlos, e.g.:
#
#         set style line 1 lt 1 lw 3.0 lc rgb "dark-red"
#
# Luego, podmos invocar as estilo con
#
#         linestyle 1
#
# O con su diminutivo:
#
#         ls 1
#
# En la curva deseada.

# %%
reset

#Definimos los estilos de línea con código RGB
set style line 1 lt 1 lw 3.0 lc rgb "dark-red"
set style line 2 lt 1 lw 3.0 lc rgb "#E9967A"
set style line 3 lt 1 lw 3.0 lc rgb "#228B22"

#definimos el borde
set border linewidth 3

#definimos el estilo
set style data lines

#ubicamos una etiqueta
set label "PDFs" at -10,2.46 tc rgb "black"

#definimos los rangos
set xrange [-10:10]
set yrange [-7:2]

#etiquetamos los sjes
set xlabel offset +0.0, +0.65
set xlabel "ln({/Symbol r}/{/Symbol n})"
set ylabel offset +0.5
set ylabel "log_{10}P({/Symbol r}/{/Symbol n})"

#definimos el espaciamiento para los ejes
set xtics 2
set ytics -7,1,0

#Definimos la posición y largo del "key"
set key left top
set key samplen 10

plot "pdf_f00.dat" using 1:2 title "t/t_{cc}=0.00" linestyle 1, "pdf_f15.dat" using 1:2 title "t/t_{cc}=0.25" linestyle 2, "pdf_f30.dat" using 1:2 title "t/t_{cc}=0.50" linestyle 3

# %% [markdown]
# Además, se pueden definir los márgenes con:
#
#     set bmargin at screen NÚMERO(0-1)
#     set tmargin at screen NÚMERO(0-1)
#     set lmargin at screen NÚMERO(0-1)
#     set rmargin at screen NÚMERO(0-1)

# %%
reset

#Definimos los estilos de línea con código RGB
set style line 1 lt 1 lw 3.0 lc rgb "dark-red"
set style line 2 lt 1 lw 3.0 lc rgb "#E9967A"
set style line 3 lt 1 lw 3.0 lc rgb "#228B22"

#definimos el borde
set border linewidth 3

#definimos el estilo
set style data lines

#ubicamos una etiqueta
set label "PDFs" at -10,2.46 tc rgb "black"

#definimos los rangos
set xrange [-10:10]
set yrange [-7:2]

#etiquetamos los sjes
set xlabel offset +0.0, +0.65
set xlabel "ln({/Symbol r}/{/Symbol n})"
set ylabel offset +0.5
set ylabel "log_{10}P({/Symbol r}/{/Symbol n})"

#definimos el espaciamiento para los ejes
set xtics 2
set ytics -7,1,0

#Definimos la posición y largo del "key"
set key left top
set key samplen 10

#Definimos los márgenes
set bmargin at screen 0.14
set tmargin at screen 0.92
set lmargin at screen 0.13
set rmargin at screen 0.94

plot "pdf_f00.dat" using 1:2 title "t/t_{cc}=0.00" linestyle 1, "pdf_f15.dat" using 1:2 title "t/t_{cc}=0.25" linestyle 2, "pdf_f30.dat" using 1:2 title "t/t_{cc}=0.50" linestyle 3

# %% [markdown]
# Para ver el estilo de ploteo, usamos show:

# %%
show style data
# Out:
# 	Data are plotted with lines

# %% [markdown]
# ### BARRAS DE ERROR

# %% [markdown]
# Para ubicar barras de error, utilizamos <b>with xyerrorbars</b>:
#
#         plot 'fichero.dat' using 1:2:(sqrt($1)):(sqrt($2)) with xyerrorbars
#
# En el ejemplo a continuación tomamos el archivo: ejemplo_datos_5.dat
#
# Y tomamos los errores como la raíz cuadrada de las columnas 1 y 2.

# %%
reset

plot 'ejemplo_datos_5.dat' using 1:2:(sqrt($1)):(sqrt($2)) with xyerrorbars

# %% [markdown]
# El comando <b>with xyerrorbars</b> acepta hasta 6 argumentos para el comando precedente <b>using</b>, como sigue:
#
#
#       using COLUMNA_X:COLUMNA_Y:ERROR_INFERIOR_X:ERROR_SUPERIOR_X:ERROR_INFERIOR_Y:ERROR_SUPERIOR_Y with xyerrorbars

# %%
reset
set key tmargin left
set datafile separator "," #Para abrir archivos .csv

plot 'ejemplo_datos_6.csv' using 1:2:($1-$5):($1+$6) with xerrorbars

# %%
reset
set key tmargin left
set datafile separator "," #Para abrir archivos .csv

plot 'ejemplo_datos_6.csv' using 1:2:($2-$7):($2+$8) with yerrorbars

# %%
reset
set key top left
set datafile separator ","

plot 'ejemplo_datos_6.csv' using 1:2:($1-$5):($1+$6):($2-$7):($2+$8) with xyerrorbars

# %% [markdown]
# También podemos graficar los datos que utilizaron ayer para el tutorial de python:
#
# 1. Copiar al archivo <b>iris.csv</b> a la carpeta donde están trabajando.
#
# 2. Insertar una línea que explique el tipo de separador, es decir las comas.
#
#         set datafile separator ","

# %%
reset

set datafile separator ","

set key at 8,4.4

plot "iris.csv" using 1:2 with points title "IRIS-data"

# %% [markdown]
# También podemos utilizar <b>splot</b> para visualizar caminos tri-dimensionales.

# %%
reset 

set view 40,40,1

splot "ejemplo_datos_3.dat" using 4:2:1 with lines, "ejemplo_datos_3.dat" using 4:1:2 with lines

# %% [markdown]
# ## 8.2. Datos en formato binario:

# %%
reset

set xrange[0:256]
set yrange[0:256]

#Usamos "with image" para que los datos se proyecten en 2D

plot "nube_k01_s19.dbl" binary array=256x256 format='%double' with image notitle

# %% [markdown]
# También podemos personalizar la paleta de colores:

# %%
reset

set xrange[0:319]
set yrange[0:319]
#set palette rgb 23,28,3

set logscale zcb
plot "k04km_320F64.dat" binary array=320x320 format='%double' with image notitle

# %% [markdown]
# Y cambiar la escala de la paleta a logaritmo:

# %%
reset

set xrange[0:256]
set yrange[0:256]
set palette rgb 23,28,3

set logscale zcb

plot "nube_k01_s19.dbl" binary array=256x256 format='%double' with image notitle

# %%
reset

#Imagen tomada de: https://es.wikipedia.org/wiki/Nebulosa_de_la_H%C3%A9lice

set xrange[0:800]
set yrange[0:800]

#set logscale zcb

plot "nebulosa.jpg" binary filetype=jpg with rgbimage

# %% [markdown]
# Ahora podemos utilizar <b>splot</b> para generar visualizar la imagen en 3D:

# %%
#reset

#set view 40,20,1

#set xrange[0:256]
#set yrange[0:256]
#set palette rgb 23,28,3
#set logscale cb

#splot "nube_k01_s19.dbl" binary array=256x256 format='%double' with image notitle

# %% [markdown]
# ## 9. Ajustes de curvas con GNUplot

# %%
reset

f(x) = a*x + b

fit f(x) 'ejemplo_datos_0.dat' using 1:2 via a,b

plot 'ejemplo_datos_0.dat' using 1:2, f(x)
# Out:
# iter      chisq       delta/lim  lambda   a             b
#    0 9.9600914888e+02   0.00e+00  6.20e-02   -3.778436e-03   8.492675e-02
#    1 2.0524819313e+02  -3.85e+05  6.20e-03    5.238515e-01  -5.597318e-01
#    2 1.8114840736e+02  -1.33e+04  6.20e-04    6.908460e-01  -1.398042e+00
#    3 1.8114814749e+02  -1.43e-01  6.20e-05    6.913959e-01  -1.400836e+00
# iter      chisq       delta/lim  lambda   a             b
#
# After 3 iterations the fit converged.
# final sum of squares of residuals : 181.148
# rel. change during last iteration : -1.43454e-06
#
# degrees of freedom    (FIT_NDF)                        : 99
# rms of residuals      (FIT_STDFIT) = sqrt(WSSR/ndf)    : 1.35269
# variance of residuals (reduced chisquare) = WSSR/ndf   : 1.82978
#
# Final set of parameters            Asymptotic Standard Error
# =======================            ==========================
# a               = 0.691396         +/- 0.04617      (6.677%)
# ...

# %%
reset

g(x) = a*sqrt(x) + b

f(x) = c*(x**4) + d*(x**3) + e*(x**2) + j*(x) + k

fit g(x) 'ejemplo_datos_0.dat' using 2:4 via a,b

fit f(x) 'ejemplo_datos_0.dat' using 2:4 via c,d,e,j,k

plot 'ejemplo_datos_0.dat' using 2:4, g(x),f(x)
# Out:
# iter      chisq       delta/lim  lambda   a             b
#    0 2.8795853989e+03   0.00e+00  1.21e+00    6.913959e-01  -1.400836e+00
#    1 2.7582787435e+02  -9.44e+05  1.21e-01    2.388895e+00   1.417045e+00
#    2 2.7566286436e+02  -5.99e+01  1.21e-02    2.434247e+00   1.382895e+00
#    3 2.7566286431e+02  -1.83e-05  1.21e-03    2.434276e+00   1.382857e+00
# iter      chisq       delta/lim  lambda   a             b
#
# After 3 iterations the fit converged.
# final sum of squares of residuals : 275.663
# rel. change during last iteration : -1.82944e-10
#
# degrees of freedom    (FIT_NDF)                        : 99
# rms of residuals      (FIT_STDFIT) = sqrt(WSSR/ndf)    : 1.66867
# variance of residuals (reduced chisquare) = WSSR/ndf   : 2.78447
#
# Final set of parameters            Asymptotic Standard Error
# =======================            ==========================
# a               = 2.43428          +/- 0.2179       (8.953%)
# ...

# %%
reset

f(x) = a*x**5 + b*x**4 + c*x**3 + d*x**2 + e*x

fit f(x) 'ejemplo_datos_0.dat' using 1:2 via a,b,c,d,e

plot 'ejemplo_datos_0.dat' using 1:2, f(x)
# Out:
# iter      chisq       delta/lim  lambda   a             b             c             d             e
#    0 6.4162370709e+11   0.00e+00  3.36e+04    2.434276e+00   1.382857e+00   6.305781e-03  -5.692137e-03  -9.183886e-01
#    1 2.0899616248e+07  -3.07e+09  3.36e+03   -1.334620e-01   1.267436e+00   6.305445e-03  -5.692176e-03  -9.185369e-01
#    2 2.1057622997e+06  -8.92e+05  3.36e+02   -4.737693e-02   4.343598e-01   6.301131e-03  -5.692850e-03  -9.216322e-01
#    3 3.3578044940e+02  -6.27e+08  3.36e+01   -9.914521e-04   1.061931e-02   6.299356e-03  -5.693012e-03  -9.213854e-01
#    4 2.1306807863e+02  -5.76e+04  3.36e+00   -6.367488e-04   7.161469e-03   6.332827e-03  -5.678302e-03  -7.696182e-01
#    5 6.3097598439e+01  -2.38e+05  3.36e-01   -1.023818e-04   1.359378e-03   5.668238e-03  -5.776926e-03  -6.272936e-02
#    6 4.1787875845e+01  -5.10e+04  3.36e-02   -6.361045e-04   1.151853e-02  -4.567151e-02  -1.536084e-02   3.008664e-01
# ...

# %%
reset

f(x) = a*x**5 + b*x**4 + c*x**3 + d*x**2 + e*x

fit f(x) 'ejemplo_datos_0.dat' using 1:2 via a,b,c,d,e

plot 'ejemplo_datos_0.dat' using 1:2:(sqrt($10/200)):(sqrt($3/400)) with xyerrorbars, f(x)
# Out:
# iter      chisq       delta/lim  lambda   a             b             c             d             e
#    0 1.6771877171e+01   0.00e+00  1.80e+02   -3.778436e-03   8.492675e-02  -6.309050e-01   1.788777e+00  -1.350772e+00
#    * 1.6771877171e+01   1.78e-09  1.80e+03   -3.778436e-03   8.492675e-02  -6.309050e-01   1.788777e+00  -1.350772e+00
#    * 1.6771877171e+01   1.25e-09  1.80e+04   -3.778436e-03   8.492675e-02  -6.309050e-01   1.788777e+00  -1.350772e+00
#    1 1.6771877171e+01   0.00e+00  1.80e+03   -3.778436e-03   8.492675e-02  -6.309050e-01   1.788777e+00  -1.350772e+00
# iter      chisq       delta/lim  lambda   a             b             c             d             e
#
# After 1 iterations the fit converged.
# final sum of squares of residuals : 16.7719
# rel. change during last iteration : 0
#
# degrees of freedom    (FIT_NDF)                        : 96
# rms of residuals      (FIT_STDFIT) = sqrt(WSSR/ndf)    : 0.41798
# ...

# %%
#set terminal postscript eps size 3.2,2.25 enhanced color dashed dashlength 2.8 linewidth 2 "Helvetica" 18
#set  terminal png size 3.2,2.25 font "Helvetica" 18

reset 


set style line 3 lt 1 lw 3.0 lc rgb "dark-red"
set style line 4 lt 1 lw 3.0 lc rgb "#E9967A"
set style line 5 lt 1 lw 3.0 lc rgb "#1E90FF"
set style line 6 lt 1 lw 3.0 lc rgb "#EE82EE"
set style line 7 lt 1 lw 3.0 lc rgb "#228B22"
set style line 8 lt 1 lw 3.0 lc rgb "#FF6347"

#set output 'Figure2.eps'

set style line 1 lt 1 lw 2.0 lc rgb "blue"

set st d l

set label "Density PDFs in model Tur-0-0" at -10,2.46 tc rgb "black"
set xrange [-10:10]
set yrange [-7:2]

set xlabel offset +0.0, +0.65
set xlabel "ln({/Symbol r}/{/Symbol n})"
set ylabel offset +0.5
set ylabel "log_{10}P({/Symbol r}/{/Symbol n})"

set bmargin at screen 0.175
set lmargin at screen 0.145

set xtics 2
set ytics -7,1,0

set bmargin at screen 0.14
set tmargin at screen 0.92
set lmargin at screen 0.13
set rmargin at screen 0.94

set key left top
set key samplen 10

plot "pdf_f00.dat" using 1:2 title "t/t_{cc}=0.00" ls 3, "pdf_f15.dat" using 1:2 title "t/t_{cc}=0.25" ls 4, "pdf_f30.dat" using 1:2 title "t/t_{cc}=0.50" ls 5, "pdf_f45.dat" using 1:2 title "t/t_{cc}=0.75" ls 6, "pdf_f60.dat" using 1:2 title "t/t_{cc}=1.00" ls 7, "pdf_f75.dat" using 1:2 title "t/t_{cc}=1.25" ls 8
