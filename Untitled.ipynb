# %%
reset

set isosamples 40, 40

#set zrange [ * : * ] noreverse nowriteback  # (currently [-1.00000:1.00000] )
splot [x=-10:10] [y=-10:10] sin(sqrt(x**2+y**2))/sqrt(x**2+y**2)
